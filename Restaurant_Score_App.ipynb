# %% [markdown]
# Keiana Dunn
# Final Project: Restaurant Health Inspection Analysis using Dash
# Objective:
# 5/8/19

# %% [markdown]
# # Import library

# %%
import dash
import dash_table_experiments as dt
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output, State

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from plotly import graph_objs as go
import json

# %% [markdown]
# # Mapbox # API key

# %%
mapbox_access_token = "pk.eyJ1Ijoia3RkMjAwMSIsImEiOiJjanUwZzBkZWYxYWdyNDRtcTB3M3Rqb2w2In0.HC_MMaor7bWiJEu7Ytp7pA"

# %% [markdown]
# # Import data

# %%
# Prior to bring data into jupyter lab, data was preprocessed in the terminal. This involved correcting and removing business postal codes  
df = pd.read_csv("restaurant_scores.csv").dropna() 
df.head(5)
# Out:
#     business_id              business_name   business_address  business_city  \
# 4          4864  DRAGON CITY BAKERY & CAFE    2367 MISSION St  San Francisco
# 12         3838                CAFE PICARO       3120 16th St  San Francisco
# 27        64380    Michael Mina Restaurant  252 California St  San Francisco
# 47         4787             TONY BALONEY'S     1098 HOWARD St  San Francisco
# 53        33700          Casa Guadalupe #3       2999 MISSION  San Francisco
#
#    business_state business_postal_code  business_latitude  business_longitude  \
# 4              CA                94110          37.759174         -122.419066
# 12             CA                94103          37.764908         -122.422442
# 27             CA                94111          37.793338         -122.399583
# 47             CA                94103          37.778033         -122.409430
# 53             CA                94110          37.749194         -122.418116
#
#            business_location  business_phone_number   inspection_id  \
# 4   (37.759174, -122.419066)           1.415583e+10   4864_20161206
# 12  (37.764908, -122.422442)           1.415543e+10   3838_20180222
# 27  (37.793338, -122.399583)           1.415535e+10  64380_20160414
# 47   (37.778033, -122.40943)           1.415586e+10   4787_20160628
# 53  (37.749194, -122.418116)           1.415588e+10  33700_20160412
#
#            inspection_date  inspection_score        inspection_type  \
# 4   12/06/2016 12:00:00 AM              84.0  Routine - Unscheduled
# 12  02/22/2018 12:00:00 AM              72.0  Routine - Unscheduled
# 27  04/14/2016 12:00:00 AM              86.0  Routine - Unscheduled
# 47  06/28/2016 12:00:00 AM              83.0  Routine - Unscheduled
# 53  04/12/2016 12:00:00 AM              90.0  Routine - Unscheduled
#
#              violation_id                              violation_description  \
# 4    4864_20161206_103157  Food safety certificate or food handler card n...
# 12   3838_20180222_103142                   Unclean nonfood contact surfaces
# 27  64380_20160414_103154       Unclean or degraded floors walls or ceilings
# 47   4787_20160628_103131                   Moderate risk vermin infestation
# 53  33700_20160412_103119  Inadequate and inaccessible handwashing facili...
#
#     risk_category
# 4        Low Risk
# 12       Low Risk
# 27       Low Risk
# 47  Moderate Risk
# 53  Moderate Risk

# %% [markdown]
# # Drop rows in such a way as to retain only n randomly chosen rows (in this case n is set to 1000)

# %%
df = df.sample(n=1000)

# %% [markdown]
# # Exploring the data

# %% [markdown]
# # Looking at index and data types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 19709 to 35357
# Data columns (total 17 columns):
# business_id              1000 non-null int64
# business_name            1000 non-null object
# business_address         1000 non-null object
# business_city            1000 non-null object
# business_state           1000 non-null object
# business_postal_code     1000 non-null object
# business_latitude        1000 non-null float64
# business_longitude       1000 non-null float64
# business_location        1000 non-null object
# business_phone_number    1000 non-null float64
# inspection_id            1000 non-null object
# inspection_date          1000 non-null object
# inspection_score         1000 non-null float64
# inspection_type          1000 non-null object
# violation_id             1000 non-null object
# violation_description    1000 non-null object
# risk_category            1000 non-null object
# dtypes: float64(4), int64(1), object(12)
# memory usage: 140.6+ KB

# %% [markdown]
# # Create column for individual totaling of risk category

# %%
def trans_risk_category(x):
    if x == 'Low Risk':
        return 1.0
    if x == 'Moderate Risk':
        return 2.0
    if x == 'High Risk':
        return 3.0
    
df['numerical_risk_category'] = df['risk_category'].apply(trans_risk_category)

# %% [markdown]
# # Remove time from "Inspection Date" since all are the same time

# %%
import datetime as dt
df["inspection_date"] = df["inspection_date"].str.replace('12:00:00 AM','')
#df["inspection_date"].dt.strftime('%Y-%b-%d')
#df["inspection_date"].sort_values()
df["inspection_date"].max()
# Out:
# '12/30/2016 '

# %% [markdown]
# # Looking at summary stats of inspection scores

# %%
df["inspection_score"].describe()
# Out:
# count    1000.000000
# mean       85.757000
# std         8.009126
# min        57.000000
# 25%        81.000000
# 50%        87.000000
# 75%        92.000000
# max        98.000000
# Name: inspection_score, dtype: float64

# %% [markdown]
# # Getting median of inspection score data

# %%
df["inspection_score"].median()
# Out:
# 87.0

# %% [markdown]
# # Verifying inspection score datatype changed to a float

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 19709 to 35357
# Data columns (total 18 columns):
# business_id                1000 non-null int64
# business_name              1000 non-null object
# business_address           1000 non-null object
# business_city              1000 non-null object
# business_state             1000 non-null object
# business_postal_code       1000 non-null object
# business_latitude          1000 non-null float64
# business_longitude         1000 non-null float64
# business_location          1000 non-null object
# business_phone_number      1000 non-null float64
# inspection_id              1000 non-null object
# inspection_date            1000 non-null object
# inspection_score           1000 non-null float64
# inspection_type            1000 non-null object
# violation_id               1000 non-null object
# violation_description      1000 non-null object
# risk_category              1000 non-null object
# numerical_risk_category    1000 non-null float64
# dtypes: float64(5), int64(1), object(12)
# memory usage: 148.4+ KB

# %% [markdown]
# # Selecting only required columns for analysis

# %%
map_data = df[["business_name", "business_address", "business_postal_code", "business_latitude", "business_latitude", "inspection_date", "inspection_id", "inspection_type", "violation_description", "inspection_score", "risk_category", "numerical_risk_category"]]
map_data.head(5)
# Out:
#                        business_name  business_address business_postal_code  \
# 19709                  PACIFIC CATCH  2027 CHESTNUT St                94123
# 29332     IRMA'S PAMPANGA RESTAURANT      2901 16th St                94103
# 46757  Osha Thai Restaurant & Lounge       311 03rd St                94107
# 11816           Harvest Urban Market       191 08th St                94103
# 23308               VALENCIA GROCERY  1300 VALENCIA St                94110
#
#        business_latitude  business_latitude inspection_date   inspection_id  \
# 19709          37.800763          37.800763     01/17/2019     305_20190117
# 29332          37.765123          37.765123     02/25/2019    2326_20190225
# 46757          37.783662          37.783662     06/27/2017   61989_20170627
# 11816          37.776384          37.776384     11/27/2018   10332_20181127
# 23308          37.752059          37.752059     10/12/2017    7646_20171012
#
#              inspection_type  \
# 19709  Routine - Unscheduled
# 29332  Routine - Unscheduled
# 46757  Routine - Unscheduled
# 11816  Routine - Unscheduled
# 23308  Routine - Unscheduled
#
#                                    violation_description  inspection_score  \
# 19709  Wiping cloths not clean or properly stored or ...              90.0
# 29332             Foods not protected from contamination              68.0
# 46757  Inadequately cleaned or sanitized food contact...              67.0
# 11816   Unapproved or unmaintained equipment or utensils              75.0
# 23308                        Low risk vermin infestation              98.0
#
#        risk_category  numerical_risk_category
# 19709       Low Risk                      1.0
# 29332  Moderate Risk                      2.0
# 46757  Moderate Risk                      2.0
# 11816       Low Risk                      1.0
# 23308       Low Risk                      1.0

# %% [markdown]
# # Total number of businesses

# %%
map_data.business_name.count()
# Out:
# 1000

# %% [markdown]
# # Restaurants grouped by postal codes

# %%
zip_code_group = map_data.groupby('business_postal_code').size()
zip_code_group.count()
# Out:
# 24

# %% [markdown]
# # What are all of the postal codes

# %%
map_data.business_postal_code.unique()
# Out:
# array(['94123', '94103', '94107', '94110', '94108', '94102', '94134',
#        '94114', '94121', '94133', '94117', '94115', '94122', '94112',
#        '94118', '94111', '94105', '94132', '94109', '94131', '94127',
#        '94116', '94124', '94104'], dtype=object)

# %% [markdown]
# # Grouped inspection scores of restaurants

# %%
restaurant_scores = map_data['inspection_score'].groupby(map_data['business_name']).size()
restaurant_scores.count()
# Out:
# 468

# %% [markdown]
# # Resturants grouped by Risk Category

# %%
category_distribution = map_data.groupby('risk_category').size()
pd.DataFrame({'Count of Restaurants within Risk Category Totals':category_distribution.values}, 
             index=category_distribution.index)
# Out:
#                Count of Restaurants within Risk Category Totals
# risk_category
# High Risk                                                   140
# Low Risk                                                    479
# Moderate Risk                                               381

# %% [markdown]
# # Group Restaurants by inspection scores

# %%
inspection_score_distribution = map_data.groupby('inspection_score').size()
pd.DataFrame({'Count of Restaurants Inspection Scores Totals':inspection_score_distribution.values}, 
             index=inspection_score_distribution.index)
# Out:
#                   Count of Restaurants Inspection Scores Totals
# inspection_score
# 57.0                                                          4
# 60.0                                                          1
# 62.0                                                          2
# 63.0                                                          1
# 64.0                                                          2
# 65.0                                                          5
# 66.0                                                          3
# 67.0                                                         15
# 68.0                                                          6
# 69.0                                                          9
# 70.0                                                         15
# 71.0                                                          5
# 72.0                                                         12
# 73.0                                                          4
# 74.0                                                         18
# 75.0                                                         13
# 76.0                                                         12
# 77.0                                                         28
# 78.0                                                         27
# 79.0                                                         22
# 80.0                                                         25
# 81.0                                                         49
# 82.0                                                         29
# 83.0                                                         33
# 84.0                                                         25
# 85.0                                                         27
# 86.0                                                         66
# 87.0                                                         55
# 88.0                                                         66
# 89.0                                                         26
# 90.0                                                         96
# 91.0                                                         14
# 92.0                                                         96
# 93.0                                                         11
# 94.0                                                         87
# 96.0                                                         56
# 98.0                                                         35

# %% [markdown]
# # Group restaurants by inspection type

# %%
inspection_type_distrubtion = map_data.groupby('inspection_type').size()
pd.DataFrame({'Count of Inspection Type Totals':inspection_type_distrubtion.values}, 
             index=inspection_type_distrubtion.index)
# Out:
#                        Count of Inspection Type Totals
# inspection_type
# Routine - Unscheduled                             1000

# %% [markdown]
# # Violation description occuring the most

# %%
df['violation_description'].max()
# Out:
# 'Wiping cloths not clean or properly stored or inadequate sanitizer'

# %% [markdown]
# # Violation occuring the least

# %%
df['violation_description'].min()
# Out:
# 'Contaminated or adulterated food'

# %% [markdown]
# # List of violation descriptions

# %%
df.violation_description.unique()
# Out:
# array(['Wiping cloths not clean or properly stored or inadequate sanitizer',
#        'Foods not protected from contamination',
#        'Inadequately cleaned or sanitized food contact surfaces',
#        'Unapproved or unmaintained equipment or utensils',
#        'Low risk vermin infestation', 'Moderate risk vermin infestation',
#        'Noncompliance with HAACP plan or variance',
#        'Insufficient hot water or running water',
#        'High risk food holding temperature',
#        'Noncompliance with shell fish tags or display',
#        'Unclean nonfood contact surfaces', 'Improper cooling methods',
#        'Improper storage of equipment utensils or linens',
#        'Permit license or inspection report not posted',
#        'Inadequate food safety knowledge or lack of certified food safety manager',
#        'Unclean or degraded floors walls or ceilings',
#        'Inadequate dressing rooms or improper storage of personal items',
#        'Inadequate and inaccessible handwashing facilities',
#        'High risk vermin infestation',
#        'Unclean or unsanitary food contact surfaces',
#        'Improper food storage',
#        'Inadequate or unsanitary refuse containers or area or no garbage service',
#        'Improper thawing methods',
#        'Inadequate warewashing facilities or equipment',
#        'Employee eating or smoking',
#        'Moderate risk food holding temperature', 'Non service animal',
#        'Food safety certificate or food handler card not available',
#        'Inadequate ventilation or lighting',
#        'Improper or defective plumbing',
#        'Unclean hands or improper use of gloves',
#        'Unauthorized or unsafe use of time as a public health control measure',
#        'Inadequate procedures or records for time as a public health control',
#        'Reservice of previously served foods',
#        'Improper reheating of food',
#        'Improper storage use or identification of toxic substances',
#        'Unsanitary employee garments hair or nails',
#        'No thermometers or uncalibrated thermometers',
#        'Unpermitted food facility', 'Contaminated or adulterated food',
#        'Other low risk violation', 'Inadequate HACCP plan record keeping',
#        'Unclean unmaintained or improperly constructed toilet facilities',
#        'Food in poor condition',
#        'Improper food labeling or menu misrepresentation',
#        'Inadequate sewage or wastewater disposal',
#        'Other moderate risk violation'], dtype=object)

# %% [markdown]
# # Counts of Violation types

# %%
# Violation_description groupby, count and sort them from largest violation by count to smallest
violation_description = map_data.groupby('violation_description').size()
violation_description_count = pd.DataFrame({'Count':violation_description.values},index = violation_description.index).sort_values(by = 'Count',ascending=False)
violation_description_count
# Out:
#                                                     Count
# violation_description
# Unclean or degraded floors walls or ceilings          110
# Unapproved or unmaintained equipment or utensils       77
# Inadequately cleaned or sanitized food contact ...     72
# Moderate risk food holding temperature                 68
# Moderate risk vermin infestation                       57
# Wiping cloths not clean or properly stored or i...     56
# Inadequate and inaccessible handwashing facilities     55
# High risk food holding temperature                     51
# Foods not protected from contamination                 45
# Improper food storage                                  41
# Low risk vermin infestation                            35
# Unclean nonfood contact surfaces                       32
# Food safety certificate or food handler card no...     24
# Inadequate food safety knowledge or lack of cer...     24
# Unclean hands or improper use of gloves                23
# Unclean or unsanitary food contact surfaces            23
# Permit license or inspection report not posted         23
# Improper cooling methods                               22
# Improper storage of equipment utensils or linens       20
# Improper thawing methods                               19
# Insufficient hot water or running water                18
# High risk vermin infestation                           16
# Improper or defective plumbing                         12
# Improper storage use or identification of toxic...     12
# Inadequate ventilation or lighting                      8
# Noncompliance with HAACP plan or variance               7
# Inadequate warewashing facilities or equipment          7
# Employee eating or smoking                              5
# Inadequate procedures or records for time as a ...      4
# Inadequate or unsanitary refuse containers or a...      4
# Other low risk violation                                3
# Inadequate dressing rooms or improper storage o...      3
# No thermometers or uncalibrated thermometers            3
# Noncompliance with shell fish tags or display           2
# Non service animal                                      2
# Reservice of previously served foods                    2
# Improper reheating of food                              2
# Unpermitted food facility                               2
# Unsanitary employee garments hair or nails              2
# Contaminated or adulterated food                        2
# Other moderate risk violation                           1
# Inadequate sewage or wastewater disposal                1
# Unauthorized or unsafe use of time as a public ...      1
# Inadequate HACCP plan record keeping                    1
# Improper food labeling or menu misrepresentation        1
# Food in poor condition                                  1
# Unclean unmaintained or improperly constructed ...      1

# %% [markdown]
# # Restaurants with multiple violations

# %%
# Looking to see if we have restaurants with multiple violations
Number_Business_Violations = map_data.groupby(['business_name','violation_description']).size()
pd.DataFrame({'Count':Number_Business_Violations.values}, index=Number_Business_Violations.index).sort_values(by='Count', ascending=False)
# Out:
#                                                                                          Count
# business_name                        violation_description
# Shanghai Dumpling King 2             Unclean or degraded floors walls or ceilings            3
# SAFEWAY STORE #964                   Inadequate and inaccessible handwashing facilities      3
# TAQUERIA CANCUN                      Unclean or degraded floors walls or ceilings            3
# KIMOCHI INC                          Moderate risk vermin infestation                        3
# 21 Taste House                       Unapproved or unmaintained equipment or utensils        2
# KING'S BAKERY                        High risk food holding temperature                      2
# TAQUERIA EL BUEN SABOR               Unclean nonfood contact surfaces                        2
# JAVA ON OCEAN                        Wiping cloths not clean or properly stored or i...      2
# CAFE LA TAZA                         Moderate risk food holding temperature                  2
# THAT'S IT MARKET                     Wiping cloths not clean or properly stored or i...      2
# Buckhorn Grill                       Unclean or degraded floors walls or ceilings            2
# Bi Rite Market                       Improper cooling methods                                2
# Tacos San Buena                      Inadequate food safety knowledge or lack of cer...      2
# PLUTO'S                              Unapproved or unmaintained equipment or utensils        2
# The Brixton                          Unclean nonfood contact surfaces                        2
# LA ALTENA                            Inadequate food safety knowledge or lack of cer...      2
# ORTEGA ELEMENTARY SCHOOL             Insufficient hot water or running water                 2
# ON THE BRIDGE                        Unapproved or unmaintained equipment or utensils        2
# LA CUMBRE                            Foods not protected from contamination                  2
# The Olive Garden Italian             Permit license or inspection report not posted          2
#                                      Unapproved or unmaintained equipment or utensils        2
# LAKESHORE ELEMENTARY SCHOOL          Inadequate and inaccessible handwashing facilities      2
# PIZZA HUT                            Unclean or degraded floors walls or ceilings            2
# HWA LEI MARKET                       Unapproved or unmaintained equipment or utensils        2
# Hornblower Cruises & Events/SF Belle Inadequately cleaned or sanitized food contact ...      2
# Sabor De San Miguel                  Foods not protected from contamination                  2
# SAI JAI THAI                         Unclean or degraded floors walls or ceilings            2
# SF BAGEL CO. (KATZ BAGELS)           Moderate risk vermin infestation                        2
# FLOWER MARKET CAFE                   Foods not protected from contamination                  2
# FOREIGN CINEMA                       Moderate risk food holding temperature                  2
# ...                                                                                        ...
# JAVA ON OCEAN                        Improper food storage                                   1
# HWA LEI MARKET                       Inadequately cleaned or sanitized food contact ...      1
#                                      Improper food storage                                   1
#                                      High risk vermin infestation                            1
# HAN IL KWAN                          Unclean hands or improper use of gloves                 1
# Glaze Teriyaki                       Inadequate and inaccessible handwashing facilities      1
#                                      Wiping cloths not clean or properly stored or i...      1
# Go Go Market & Deli                  Moderate risk vermin infestation                        1
#                                      Unclean or degraded floors walls or ceilings            1
# Good Life Grocery, The               Inadequately cleaned or sanitized food contact ...      1
# Green Papaya Restaurant              High risk food holding temperature                      1
#                                      Moderate risk food holding temperature                  1
# HAAGEN-DAZS #561                     Unapproved or unmaintained equipment or utensils        1
#                                      Unclean or degraded floors walls or ceilings            1
# HAMANO SUSHI                         Foods not protected from contamination                  1
#                                      Moderate risk vermin infestation                        1
# HAN IL KWAN                          Unclean or unsanitary food contact surfaces             1
# HWA LEI MARKET                       Food in poor condition                                  1
# HARVEY'S                             Improper storage of equipment utensils or linens        1
# HIGHER GROUNDS                       Food safety certificate or food handler card no...      1
#                                      Inadequate and inaccessible handwashing facilities      1
#                                      Moderate risk food holding temperature                  1
#                                      Permit license or inspection report not posted          1
# HONG KONG RESTAURANT                 High risk food holding temperature                      1
#                                      Improper storage use or identification of toxic...      1
#                                      Unclean hands or improper use of gloves                 1
#                                      Unclean or degraded floors walls or ceilings            1
# HOOVER MIDDLE SCHOOL                 Unapproved or unmaintained equipment or utensils        1
# HUNAN EMPIRE                         Unclean or degraded floors walls or ceilings            1
# Zona Rosa                            Moderate risk vermin infestation                        1
#
# [940 rows x 1 columns]

# %% [markdown]
# # Create athe text information that will be used in text box for application

# %%
df['text'] = df['business_name'] +"<br>"+ df['risk_category'] +"<br>"+ df['inspection_type']+"<br>"+ df['inspection_score'].astype(str)+"<br>"+ df['violation_description'].astype(str)
df['text'].head(2)
# Out:
# 19709    PACIFIC CATCH<br>Low Risk<br>Routine - Unsched...
# 29332    IRMA'S PAMPANGA RESTAURANT<br>Moderate Risk<br...
# Name: text, dtype: object

# %% [markdown]
# #  Create color scale and color variables

# %%
# Color scale for inspection score map list
scl1 = [[0, 'red'],[0.5,"rgb(255, 255, 0)"], [1.0, 'green']]
# Color scale for risk category map list
scl2 = [[0, 'green'],[0.5,"rgb(255, 255, 0)"],[1.0,"rgb(255, 0, 0)"] ]
# Names for risk category color scale list
color_names= [' ','Low','Moderate','High']
# Iterate through list of color names
color_vals = list(range(len(color_names)))
# Return color Vals list
num_colors = len(color_vals)

# %% [markdown]
# # Plot map graph

# %%
# The graph  created in Dash is more detailed with a color scale display different colored plots. I was not able to include these features 
# that I created in Dash but here is the basic code used. 
import plotly.plotly as py
import plotly.offline as offline
import matplotlib as plt 
# %matplotlib inline

mapbox_access_token = "pk.eyJ1Ijoia3RkMjAwMSIsImEiOiJjanUwZzBkZWYxYWdyNDRtcTB3M3Rqb2w2In0.HC_MMaor7bWiJEu7Ytp7pA"

# Hover box information
df['text'] = df['business_name'] +"<br>"+ df['risk_category'] +"<br>"+ df['inspection_type']+"<br>"+ df['inspection_score'].astype(str)+"<br>"+ df['violation_description'].astype(str)

#Basic code to display map 1 figure
trace = go.Scattermapbox(lat = df["business_latitude"], lon = df["business_longitude"], text= df['text'], mode="markers+text", 
                         textposition="top center") 
                         
data = [trace]

#define map layout - access token (API), which location map should be centered on
layout = go.Layout(mapbox=dict(accesstoken=mapbox_access_token, center=dict(lat=37.74, lon=-122.46), zoom=11.0))

#finalize data and layout
figure = go.Figure(data = data, layout = layout)

#Display map
offline.plot(figure)
# Out:
# 'temp-plot.html'

# %% [markdown]
# # Plot Histogram

# %%
#Basic code to display histogram 1 figure
#trace = go.Histogram(x=df['inspection_score'])

#data = [trace]

#layout = go.Layout(mapbox=dict(accesstoken=mapbox_access_token,
                #    bargap=0.01,
               #     xaxis=go.layout.XAxis(title='Inspection Scores'),
                #    yaxis=go.layout.YAxis(title='Count'))
                #    )

#figure1 = go.Figure(data = data, layout = layout)

#Display map
#offline.plot(figure1)
